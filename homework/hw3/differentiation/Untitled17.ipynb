# %%
import numpy as np
import random as rand
from numpy import empty 

N = 25 # number of people

def mag(x):
    return np.sqrt(x[0]**2. + x[1]**2.)

def distance(N,r):
    s = 0. # distance travled
    for i in range(N):
        s = s + mag(r[i+1] - r[i])
    return s

# assigning city locations, calculating inital distance travled
r = empty([N+1,2],float)

for i in range(N):
    r[i,0] = np.random.random()
    r[i,1] = np.random.random()
    
r[N] = r[0]

# calculate inital distance
D = distance(N,r)

D_saved = []

for dummy_counter in range(1000):
    # pick 2 cities to swap
    i = np.random.randint(N)
    j = np.random.randint(N)
    
    # in case accidentally pick same city, keep randomizing until not same
    while i == j:
        i = np.random.randint(N)
        j = np.random.randint(N)
    
    # swap cities to calculate change in distance
    oldD = D
    r[i,0],r[j,0] = r[j,0],r[i,0] # new r of j = old r of j, does both swaps automatically once, swapping x positions for i and j 
    r[i,1],r[j,1] = r[j,1],r[i,1] # swapping y positions
    D = distance(N,r)
    
    deltaD = D - oldD #is distance bigger or smaller? difference in distances, want it to be a - number if it is a good swap
    
    if deltaD > 0: # if bad swap, swap it back
        r[i,0], r[j,0] = r[j,0], r[i,0] 
        r[i,1], r[j,1] = r[j,1], r[i,1]
        print("bad swap, swapping back")
        
        D_saved.append(D)
        print(deltaD)
# Out:
# bad swap, swapping back
# 0.06120303854565812
# bad swap, swapping back
# 0.042339012426651834
# bad swap, swapping back
# 0.37609653437950463
# bad swap, swapping back
# 0.047487740587497385
# bad swap, swapping back
# 0.08846968165345181
# bad swap, swapping back
# 0.8684013532924997
# bad swap, swapping back
# 0.2223922692195739
# bad swap, swapping back
# 0.02392159506066527
# bad swap, swapping back
# 0.0037221902069504154
# bad swap, swapping back
# 1.0558879211976908
# bad swap, swapping back
# 0.5344842538874648
# bad swap, swapping back
# 0.9707911475256967
# bad swap, swapping back
# 0.18324503804728387
# bad swap, swapping back
# 0.7674654473653604
# bad swap, swapping back
# 0.09676209180268636
# bad swap, swapping back
# 0.4146553708387124
# bad swap, swapping back
# 0.29274867132998317
# bad swap, swapping back
# 0.05360793490366689
# bad swap, swapping back
# 0.3524458097465004
# bad swap, swapping back
# 0.011094008312783288
# bad swap, swapping back
# 1.1907897742046405
# bad swap, swapping back
# 0.10182729643798538
# bad swap, swapping back
# 0.22554561022982078
# bad swap, swapping back
# 0.9538809984183096
# bad swap, swapping back
# 1.0584578223609
# bad swap, swapping back
# 0.14108356484205942
# bad swap, swapping back
# 0.6938871723973588
# bad swap, swapping back
# 0.2674006640871429
# bad swap, swapping back
# 0.08442243454500975
# bad swap, swapping back
# 0.37542086516061524
# bad swap, swapping back
# 0.0823942121755934
# bad swap, swapping back
# 0.4141995491074866
# bad swap, swapping back
# 0.40497526571224896
# bad swap, swapping back
# 0.23123555108905514
# bad swap, swapping back
# 0.5198444829354685
# bad swap, swapping back
# 2.162153510240092
# bad swap, swapping back
# 0.002493871021744809
# bad swap, swapping back
# 0.7446014145846167
# bad swap, swapping back
# 0.21539641027514023
# bad swap, swapping back
# 0.06591983844796445
# bad swap, swapping back
# 0.31532921836763883
# bad swap, swapping back
# 0.3318440652731933
# bad swap, swapping back
# 0.5630347913323916
# bad swap, swapping back
# 0.42448748545254666
# bad swap, swapping back
# 0.3758023288701491
# bad swap, swapping back
# 1.4047400076193917
# bad swap, swapping back
# 0.7205689242232385
# bad swap, swapping back
# 0.21677822206751962
# bad swap, swapping back
# 1.5546808932678076
# bad swap, swapping back
# 1.3946316633739873
# bad swap, swapping back
# 0.03721731363394554
# bad swap, swapping back
# 0.46754627786474146
# bad swap, swapping back
# 0.7372995953707733
# bad swap, swapping back
# 0.0911539630962892
# bad swap, swapping back
# 0.4018941174163775
# bad swap, swapping back
# 0.23217411397936516
# bad swap, swapping back
# 1.1127294289967633
# bad swap, swapping back
# 0.39400771996980843
# bad swap, swapping back
# 0.15693635457642152
# bad swap, swapping back
# 0.5602429942419054
# bad swap, swapping back
# 0.0956530044307371
# bad swap, swapping back
# 0.5659540728245513
# bad swap, swapping back
# 1.5113324347361505
# bad swap, swapping back
# 0.09294911949737994
# bad swap, swapping back
# 0.4428353137636627
# bad swap, swapping back
# 0.03783802829430982
# bad swap, swapping back
# 1.1570742139116863
# bad swap, swapping back
# 1.1057706390488438
# bad swap, swapping back
# 0.008817787386444564
# bad swap, swapping back
# 0.5665272514269724
# bad swap, swapping back
# 0.9273184951376585
# bad swap, swapping back
# 0.2051530959212471
# bad swap, swapping back
# 0.06627841409300572
# bad swap, swapping back
# 0.46785530019510446
# bad swap, swapping back
# 0.3415197898848703
# bad swap, swapping back
# 0.015572149459460505
# bad swap, swapping back
# 0.05406503037855259
# bad swap, swapping back
# 0.06996989119102182
# bad swap, swapping back
# 0.8985712727258601
# bad swap, swapping back
# 0.219559887181223
# bad swap, swapping back
# 0.2593294689908827
# bad swap, swapping back
# 1.1450750599720099
# bad swap, swapping back
# 0.5648787695772945
# bad swap, swapping back
# 1.8848614666809524
# bad swap, swapping back
# 0.18548432741440912
# bad swap, swapping back
# 0.6501769669541684
# bad swap, swapping back
# 0.8808925183592038
# bad swap, swapping back
# 0.3303201256403927
# bad swap, swapping back
# 0.6299028529563664
# bad swap, swapping back
# 0.18431352460684103
# bad swap, swapping back
# 0.18745402782451315
# bad swap, swapping back
# 0.13705056805484972
# bad swap, swapping back
# 0.017995760825943563
# bad swap, swapping back
# 0.009212253786540003
# bad swap, swapping back
# 1.0877003943052923
# bad swap, swapping back
# 0.6569282821879554
# bad swap, swapping back
# 0.6777407181099715
# bad swap, swapping back
# 0.6168281968050664
# bad swap, swapping back
# 1.427088886864274
# bad swap, swapping back
# 0.281724527722389
# bad swap, swapping back
# 0.20687508790277853
# bad swap, swapping back
# 0.2617791261240612
# bad swap, swapping back
# 0.46055854927806195
# bad swap, swapping back
# 1.0317803026773582
# bad swap, swapping back
# 2.184093289668022
# bad swap, swapping back
# 0.4938371892166806
# bad swap, swapping back
# 0.6673975190553865
# bad swap, swapping back
# 1.4983472094700971
# bad swap, swapping back
# 0.34154703261780384
# bad swap, swapping back
# 0.02324641563190788
# bad swap, swapping back
# 0.6053104675651699
# bad swap, swapping back
# 0.3503538007537923
# bad swap, swapping back
# 1.6566790465692716
# bad swap, swapping back
# 0.35065697472881574
# bad swap, swapping back
# 1.101351129648421
# bad swap, swapping back
# 0.09880116030054431
# bad swap, swapping back
# 0.10214387577277151
# bad swap, swapping back
# 0.16303561935761657
# bad swap, swapping back
# 1.1808884421033277
# bad swap, swapping back
# 0.741079566257854
# bad swap, swapping back
# 0.3950155496419754
# bad swap, swapping back
# 0.5136045683074553
# bad swap, swapping back
# 0.5185634205764735
# bad swap, swapping back
# 0.009071222138263835
# bad swap, swapping back
# 0.3523615735041492
# bad swap, swapping back
# 0.5732831717752092
# bad swap, swapping back
# 0.11163742034270285
# bad swap, swapping back
# 0.8356372511595467
# bad swap, swapping back
# 0.5565834010254633
# bad swap, swapping back
# 0.18430747293047567
# bad swap, swapping back
# 0.396425197776626
# bad swap, swapping back
# 0.7914002076043065
# bad swap, swapping back
# 1.5556157657878007
# bad swap, swapping back
# 0.020713754717917254
# bad swap, swapping back
# 0.6276784832759024
# bad swap, swapping back
# 0.2998911611323223
# bad swap, swapping back
# 1.7962826326726926
# bad swap, swapping back
# 0.39140801176620776
# bad swap, swapping back
# 0.23964273063128871
# bad swap, swapping back
# 0.8903989793257878
# bad swap, swapping back
# 0.3166781929244529
# bad swap, swapping back
# 0.07083164850675061
# bad swap, swapping back
# 0.1400049050178609
# bad swap, swapping back
# 0.4686200461947667
# bad swap, swapping back
# 0.38636914215592455
# bad swap, swapping back
# 0.3076705043312362
# bad swap, swapping back
# 0.24923629081981247
# bad swap, swapping back
# 0.3185449409756398
# bad swap, swapping back
# 0.09668378907705488
# bad swap, swapping back
# 0.009105791766089055
# bad swap, swapping back
# 0.9687176459718891
# bad swap, swapping back
# 0.0094260727113884
# bad swap, swapping back
# 0.16838898099056543
# bad swap, swapping back
# 0.3298188239979094
# bad swap, swapping back
# 0.8986904323940781
# bad swap, swapping back
# 0.005032899220353215
# bad swap, swapping back
# 0.5628889185104775
# bad swap, swapping back
# 1.521979949166763
# bad swap, swapping back
# 0.12887728359082296
# bad swap, swapping back
# 1.6090804843253395
# bad swap, swapping back
# 0.1868299157380875
# bad swap, swapping back
# 0.2814510241594128
# bad swap, swapping back
# 0.5958480045498469
# bad swap, swapping back
# 0.6749109841339607
# bad swap, swapping back
# 1.5973104615905012
# bad swap, swapping back
# 1.0983295400336068
# bad swap, swapping back
# 0.9294955118787556
# bad swap, swapping back
# 0.7230768503960832
# bad swap, swapping back
# 1.0410668768782187
# bad swap, swapping back
# 1.586057879161892
# bad swap, swapping back
# 0.16871894087301165
# bad swap, swapping back
# 0.5900009383900517
# bad swap, swapping back
# 0.6693529414586106
# bad swap, swapping back
# 0.3484312220816985
# bad swap, swapping back
# 0.6418381528807942
# bad swap, swapping back
# 0.20899521122225195
# bad swap, swapping back
# 0.9035028212386624
# bad swap, swapping back
# 0.5635519953165335
# bad swap, swapping back
# 0.1616644083235972
# bad swap, swapping back
# 1.66480818260127
# bad swap, swapping back
# 0.5769803940448881
# bad swap, swapping back
# 1.1850706358566754
# bad swap, swapping back
# 0.9281726477922128
# bad swap, swapping back
# 0.22052989313810833
# bad swap, swapping back
# 0.15998987346003446
# bad swap, swapping back
# 1.021374336613297
# bad swap, swapping back
# 0.1607110690125193
# bad swap, swapping back
# 0.9691010523858701
# bad swap, swapping back
# 1.0188285106438055
# bad swap, swapping back
# 0.0065816347637923656
# bad swap, swapping back
# 0.6030675913762025
# bad swap, swapping back
# 0.204982536309263
# bad swap, swapping back
# 0.14233173909078722
# bad swap, swapping back
# 0.9354703438935772
# bad swap, swapping back
# 0.2012201126081017
# bad swap, swapping back
# 0.4942518702215537
# bad swap, swapping back
# 0.0005992254877149605
# bad swap, swapping back
# 0.4797772856890372
# bad swap, swapping back
# 0.46298523065059705
# bad swap, swapping back
# 0.06048397341022138
# bad swap, swapping back
# 0.8002525421690212
# bad swap, swapping back
# 0.4110906654891693
# bad swap, swapping back
# 0.6345566178069628
# bad swap, swapping back
# 0.3032309531952091
# bad swap, swapping back
# 0.7753171505744128
# bad swap, swapping back
# 0.39401564821473656
# bad swap, swapping back
# 0.46125367840386744
# bad swap, swapping back
# 0.2546194246227955
# bad swap, swapping back
# 0.9076638677494344
# bad swap, swapping back
# 0.11880635473375989
# bad swap, swapping back
# 1.0327521604715937
# bad swap, swapping back
# 0.37748075650856805
# bad swap, swapping back
# 1.4017518372885753
# bad swap, swapping back
# 0.06139148256279725
# bad swap, swapping back
# 0.17929053733030997
# bad swap, swapping back
# 0.6946412546138827
# bad swap, swapping back
# 1.0732657628222686
# bad swap, swapping back
# 1.736425933696216
# bad swap, swapping back
# 0.55070067090797
# bad swap, swapping back
# 0.5444767979139051
# bad swap, swapping back
# 0.7189932327558584
# bad swap, swapping back
# 1.473272909257739
# bad swap, swapping back
# 0.8947567937418537
# bad swap, swapping back
# 0.20786356892805458
# bad swap, swapping back
# 0.5721683509553834
# bad swap, swapping back
# 1.152485490583711
# bad swap, swapping back
# 0.08252907835706047
# bad swap, swapping back
# 1.7573165311721475
# bad swap, swapping back
# 0.09932129588213456
# bad swap, swapping back
# 0.023196324148845093
# bad swap, swapping back
# 1.0180103132281815
# bad swap, swapping back
# 0.5632686400380393
# bad swap, swapping back
# 0.11533312780017724
# bad swap, swapping back
# 0.268797432038955
# bad swap, swapping back
# 1.776865010899897
# bad swap, swapping back
# 0.5597346453944176
# bad swap, swapping back
# 0.24914622451277957
# bad swap, swapping back
# 0.2794023329052422
# bad swap, swapping back
# 0.4133749489836358
# bad swap, swapping back
# 0.004328801198708376
# bad swap, swapping back
# 0.021334082604822058
# bad swap, swapping back
# 0.08799224094146751
# bad swap, swapping back
# 0.1174674683373027
# bad swap, swapping back
# 0.6355258681577602
# bad swap, swapping back
# 1.5984304923845016
# bad swap, swapping back
# 0.004841601219620628
# bad swap, swapping back
# 0.9843049892947171
# bad swap, swapping back
# 0.09672170285244519
# bad swap, swapping back
# 1.7638103598229335
# bad swap, swapping back
# 1.6720638903894134
# bad swap, swapping back
# 0.12988477588356062
# bad swap, swapping back
# 0.5978028787910965
# bad swap, swapping back
# 0.23975394342990697
# bad swap, swapping back
# 0.3060751014680374
# bad swap, swapping back
# 0.5221033056589466
# bad swap, swapping back
# 0.5339700044067612
# bad swap, swapping back
# 0.9503492305025709
# bad swap, swapping back
# 0.6423817474192859
# bad swap, swapping back
# 0.9047865106354749
# bad swap, swapping back
# 0.41628998332212674
# bad swap, swapping back
# 0.13470992587584973
# bad swap, swapping back
# 1.1223494141798511
# bad swap, swapping back
# 0.6730511129783654
# bad swap, swapping back
# 0.09535655114980734
# bad swap, swapping back
# 0.5903254825468558
# bad swap, swapping back
# 1.361185728295796
# bad swap, swapping back
# 0.1750411361237827
# bad swap, swapping back
# 0.6515687130320806
# bad swap, swapping back
# 0.02334060922821557
# bad swap, swapping back
# 0.5814609223537097
# bad swap, swapping back
# 0.5551961573879982
# bad swap, swapping back
# 0.6200483025561017
# bad swap, swapping back
# 0.647225875255744
# bad swap, swapping back
# 0.6279748977807884
# bad swap, swapping back
# 0.028519002816235428
# bad swap, swapping back
# 1.8582561575404508
# bad swap, swapping back
# 0.07665962750217581
# bad swap, swapping back
# 1.3630230228802418
# bad swap, swapping back
# 0.8408313527897775
# bad swap, swapping back
# 2.0279403663720252
# bad swap, swapping back
# 0.35039925602678146
# bad swap, swapping back
# 1.019101680957725
# bad swap, swapping back
# 1.0209590341572987
# bad swap, swapping back
# 0.48966742645209393
# bad swap, swapping back
# 0.31502496722290374
# bad swap, swapping back
# 1.6096766423759377
# bad swap, swapping back
# 0.19906080536623527
# bad swap, swapping back
# 1.134964752636133
# bad swap, swapping back
# 1.6222505830079648
# bad swap, swapping back
# 0.2376226452664678
# bad swap, swapping back
# 0.5999118361551545
# bad swap, swapping back
# 0.3935271431166072
# bad swap, swapping back
# 0.26248920287797084
# bad swap, swapping back
# 0.043327318329151154
# bad swap, swapping back
# 0.1700000196667517
# bad swap, swapping back
# 1.3501791075356717
# bad swap, swapping back
# 1.3154522718399608
# bad swap, swapping back
# 0.17683248982974575
# bad swap, swapping back
# 1.346207489042861
# bad swap, swapping back
# 1.6816528653268392
# bad swap, swapping back
# 0.9567594033970881
# bad swap, swapping back
# 0.28947068492067274
# bad swap, swapping back
# 0.3240187457144721
# bad swap, swapping back
# 0.13817020860596507
# bad swap, swapping back
# 0.20942539876932464
# bad swap, swapping back
# 0.3011593381629254
# bad swap, swapping back
# 0.2724600632577783
# bad swap, swapping back
# 0.8347256675764481
# bad swap, swapping back
# 0.7582475328114597
# bad swap, swapping back
# 0.33602326079141775
# bad swap, swapping back
# 0.051304429703051824
# bad swap, swapping back
# 0.10785542730600284
# bad swap, swapping back
# 0.27784321559717284
# bad swap, swapping back
# 0.2992642206653464
# bad swap, swapping back
# 0.36378387144972457
# bad swap, swapping back
# 1.0031485533108366
# bad swap, swapping back
# 0.11215119993677014
# bad swap, swapping back
# 1.1454787428360067
# bad swap, swapping back
# 0.3434304275606639
# bad swap, swapping back
# 0.5167460762636171
# bad swap, swapping back
# 0.617371568557493
# bad swap, swapping back
# 1.5121599123245772
# bad swap, swapping back
# 1.48949603577325
# bad swap, swapping back
# 0.23035691330927577
# bad swap, swapping back
# 1.441913770761726
# bad swap, swapping back
# 0.3731065740068136
# bad swap, swapping back
# 0.34000107362511756
# bad swap, swapping back
# 0.5084913066623624
# bad swap, swapping back
# 0.13531457373265354
# bad swap, swapping back
# 0.18060692760628427
# bad swap, swapping back
# 0.4641345640130421
# bad swap, swapping back
# 0.033994734991150466
# bad swap, swapping back
# 1.051588972084243
# bad swap, swapping back
# 0.786267919174934
# bad swap, swapping back
# 0.23737241690108846
# bad swap, swapping back
# 0.3816917594055589
# bad swap, swapping back
# 0.4777468831308056
# bad swap, swapping back
# 0.9621049948703533
# bad swap, swapping back
# 0.3327176099362017
# bad swap, swapping back
# 0.03007580150072897
# bad swap, swapping back
# 0.9549389266898718
# bad swap, swapping back
# 0.14756435633315412
# bad swap, swapping back
# 0.19485446151596264
# bad swap, swapping back
# 0.08940324439434022
# bad swap, swapping back
# 0.021718226446809652
# bad swap, swapping back
# 0.4912974192807624
# bad swap, swapping back
# 0.12709833983680774
# bad swap, swapping back
# 0.4845846361920447
# bad swap, swapping back
# 0.24055214797177804
# bad swap, swapping back
# 0.6183957591175702
# bad swap, swapping back
# 0.7580760145392311
# bad swap, swapping back
# 0.1248815690254812
# bad swap, swapping back
# 1.4997938948069613
# bad swap, swapping back
# 0.31271528335629384
# bad swap, swapping back
# 1.991043053960242
# bad swap, swapping back
# 0.343290052683038
# bad swap, swapping back
# 0.15775240419530512
# bad swap, swapping back
# 0.07089459753446725
# bad swap, swapping back
# 0.3356433319511627
# bad swap, swapping back
# 0.6477489835913008
# bad swap, swapping back
# 1.1910422047519589
# bad swap, swapping back
# 0.09490261156101276
# bad swap, swapping back
# 0.12870135884805123
# bad swap, swapping back
# 0.15201015465702739
# bad swap, swapping back
# 0.39922320861430016
# bad swap, swapping back
# 0.5805497588262849
# bad swap, swapping back
# 1.1720683200029889
# bad swap, swapping back
# 0.1338941018570292
# bad swap, swapping back
# 0.863981196497166
# bad swap, swapping back
# 0.7093873810284173
# bad swap, swapping back
# 1.1570231393671975
# bad swap, swapping back
# 0.7401085805466856
# bad swap, swapping back
# 0.7228545733258969
# bad swap, swapping back
# 0.46696024184081963
# bad swap, swapping back
# 0.9528056754075322
# bad swap, swapping back
# 0.9261662576451926
# bad swap, swapping back
# 0.8321393630039751
# bad swap, swapping back
# 0.5996970110209148
# bad swap, swapping back
# 0.2846217759937062
# bad swap, swapping back
# 0.4601890401330646
# bad swap, swapping back
# 0.12462410529865053
# bad swap, swapping back
# 0.5117839038106986
# bad swap, swapping back
# 0.0998404332267846
# bad swap, swapping back
# 0.07209773120255747
# bad swap, swapping back
# 1.1398293701775568
# bad swap, swapping back
# 1.3447586211311915
# bad swap, swapping back
# 0.2778852960987628
# bad swap, swapping back
# 0.9663415371424016
# bad swap, swapping back
# 0.1484490884782339
# bad swap, swapping back
# 0.7003649387379536
# bad swap, swapping back
# 0.9301821202310165
# bad swap, swapping back
# 0.36264956790333613
# bad swap, swapping back
# 0.8139675889182172
# bad swap, swapping back
# 2.0113089966571085
# bad swap, swapping back
# 0.7448426337838328
# bad swap, swapping back
# 0.14048195585533385
# bad swap, swapping back
# 0.11976681760392793
# bad swap, swapping back
# 0.05822952482268562
# bad swap, swapping back
# 0.4901613989647977
# bad swap, swapping back
# 0.044363020279611476
# bad swap, swapping back
# 0.14255365721623114
# bad swap, swapping back
# 0.9726129332001126
# bad swap, swapping back
# 1.6346203203993888
# bad swap, swapping back
# 1.803767701456426
# bad swap, swapping back
# 0.14209223580457575
# bad swap, swapping back
# 0.5933983655216952
# bad swap, swapping back
# 0.9589096827100292
# bad swap, swapping back
# 1.4569601603346527
# bad swap, swapping back
# 0.18355024555921418
# bad swap, swapping back
# 0.30429128851533527
# bad swap, swapping back
# 0.40416937391615626
# bad swap, swapping back
# 0.3814265367468259
# bad swap, swapping back
# 1.2395567607500482
# bad swap, swapping back
# 0.8934952291050742
# bad swap, swapping back
# 0.12853239737488842
# bad swap, swapping back
# 0.46714864133464573
# bad swap, swapping back
# 0.9126448101274285
# bad swap, swapping back
# 0.023909783046502042
# bad swap, swapping back
# 0.5787805544038953
# bad swap, swapping back
# 0.6839421551583378
# bad swap, swapping back
# 0.5846327426170497
# bad swap, swapping back
# 0.28884216243246286
# bad swap, swapping back
# 1.363884534069518
# bad swap, swapping back
# 0.43197357622592136
# bad swap, swapping back
# 0.48631926569259143
# bad swap, swapping back
# 0.6113437514147293
# bad swap, swapping back
# 0.7331323467836182
# bad swap, swapping back
# 0.05952429484816513
# bad swap, swapping back
# 0.5888556379192877
# bad swap, swapping back
# 0.254513574811984
# bad swap, swapping back
# 0.10872394265695284
# bad swap, swapping back
# 0.9054738914464107
# bad swap, swapping back
# 0.10061420333871851
# bad swap, swapping back
# 0.4008079683984924
# bad swap, swapping back
# 0.11652608943625786
# bad swap, swapping back
# 0.49248961053639206
# bad swap, swapping back
# 0.3784835194035008
# bad swap, swapping back
# 0.03609641088412907
# bad swap, swapping back
# 0.18212935164069144
# bad swap, swapping back
# 0.9664268744056272
# bad swap, swapping back
# 1.4109826582441531
# bad swap, swapping back
# 0.8154397451363007
# bad swap, swapping back
# 0.5572654573913276
# bad swap, swapping back
# 0.07836517214067662
# bad swap, swapping back
# 0.015171878050480814
# bad swap, swapping back
# 1.1119276927015598
# bad swap, swapping back
# 0.0409985141945306
# bad swap, swapping back
# 0.6851448570329417
# bad swap, swapping back
# 0.680024920156626
# bad swap, swapping back
# 0.15398819901044192
# bad swap, swapping back
# 0.4414871644022398
# bad swap, swapping back
# 1.2214682341058687
# bad swap, swapping back
# 1.6781668410271262
# bad swap, swapping back
# 0.5985839125584818
# bad swap, swapping back
# 0.00782217100226923
# bad swap, swapping back
# 1.387671815812812
# bad swap, swapping back
# 0.2523982097941637
# bad swap, swapping back
# 1.8459686853536539
# bad swap, swapping back
# 0.3649353342707258
# bad swap, swapping back
# 1.7342014796201592
# bad swap, swapping back
# 0.14931434566449653
# bad swap, swapping back
# 0.01986999885831331
# bad swap, swapping back
# 0.26491930200929126
# bad swap, swapping back
# 0.9367732161888274
# bad swap, swapping back
# 0.31563746029987527
# bad swap, swapping back
# 0.27418922374497257
# bad swap, swapping back
# 0.20443718789623588
# bad swap, swapping back
# 0.32442952902226807
# bad swap, swapping back
# 0.7192265581663086
# bad swap, swapping back
# 0.016493549636262372
# bad swap, swapping back
# 0.7729228903897329
# bad swap, swapping back
# 1.1746433537454948
# bad swap, swapping back
# 0.5291890538257675
# bad swap, swapping back
# 0.08672097357417918
# bad swap, swapping back
# 0.15571975609868005
# bad swap, swapping back
# 0.08761637344952256
# bad swap, swapping back
# 1.388442614172213
# bad swap, swapping back
# 1.2673984189595586
# bad swap, swapping back
# 0.5836394338568223
# bad swap, swapping back
# 0.3551265357473632
# bad swap, swapping back
# 0.011165464783744028
# bad swap, swapping back
# 0.7724383175593061
# bad swap, swapping back
# 0.13145934458398045
# bad swap, swapping back
# 0.019476584948552755
# bad swap, swapping back
# 0.4239876445725468
# bad swap, swapping back
# 0.2464085262602591
# bad swap, swapping back
# 1.0848289146522276
# bad swap, swapping back
# 0.0019018687727445638
# bad swap, swapping back
# 2.1461605931675756
# bad swap, swapping back
# 2.0931736284004714
# bad swap, swapping back
# 0.2757839398723103
# bad swap, swapping back
# 0.9223738934599037
# bad swap, swapping back
# 0.854497008513956
# bad swap, swapping back
# 0.9223738934599055
# bad swap, swapping back
# 0.8347571331720154
# bad swap, swapping back
# 1.878645267550251
# bad swap, swapping back
# 0.1858744228860587
# bad swap, swapping back
# 0.8830947469025059
# bad swap, swapping back
# 1.6394847447304457
# bad swap, swapping back
# 1.423616220842126
